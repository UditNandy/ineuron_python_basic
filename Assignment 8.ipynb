# %% [markdown]
# ### 1.Is the Python Standard Library included with PyInputPlus?

# %% [markdown]
# No it is not included in Pthon Standard Library

# %% [markdown]
# ### 2.Why is PyInputPlus commonly imported with import pyinputplus as pypi?

# %% [markdown]
# It is done so that we can call PyInputPlus with a shorter name when called in future

# %% [markdown]
# ### 3.How do you distinguish between inputInt() and inputFloat()?

# %% [markdown]
# inputInt():Accepts an integer value
#
# inputInt():Accepts a float value

# %% [markdown]
# ### 4.Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?

# %% [markdown]
# pypi.inputInt(prompt="",min=0,lessThan=100)

# %% [markdown]
# ### 5.What is transferred to the keyword arguments allowRegexes and blockRegexes?

# %% [markdown]
# In allowRegexes we can put a set of Regex strings which would be allowed
#
# In blockRegexes we can put a set of Regex strings which will not be allowed

# %% [markdown]
# ### 6.If a blank input is entered three times, what does inputStr(limit=3) do?

# %% [markdown]
# RetryLimitException is thrown

# %% [markdown]
# ### 7.If blank input is entered three times, what does inputStr(limit=3, default='hello') do?

# %% [markdown]
# Instead of throwing any exception 'hello' is printed at last
