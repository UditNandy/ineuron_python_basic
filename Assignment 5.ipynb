# %% [markdown]
# ### 1. What does an empty dictionary's code look like?

# %% [markdown]
# {}

# %% [markdown]
# ### 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
d={'foo':42}
d['foo']

## So the value is 42
# Out:
# 42

# %% [markdown]
# ### 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# A list is an ordered sequence where as dictionary is an unordered sequence
#
# In list we have predefined keys where as in dictionary we can give our own index known as keys

# %% [markdown]
# ### 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam={'bar':100}
spam['foo']

## We can clearly see its giving error as foo is not a key in spam
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-6fc2ef8c7204> in <module>
#       1 spam={'bar':100}
# ----> 2 spam['foo']
#       3
#       4 ## We can clearly see its giving error as foo is not a key in spam
#
# KeyError: 'foo'

# %% [markdown]
# ### 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %% [markdown]
# cat in spam check if there is any value called cat in the dictionary
#
# cat in spam.keys() check if cat is a key in spam

# %% [markdown]
# ### 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# cat in spam check if there is any value called cat in the dictionary
#
# cat in spam.keys() check if cat is a value in spam
#
# So there is no difference

# %% [markdown]
# ### 7. What is a shortcut for the following code?
# if 'color' not in spam:
#     spam['color'] = 'black'

# %% [markdown]
# spam.setdefault('color','green')

# %% [markdown]
# ### 8. How do you "pretty print" dictionary values using which module and function?

# %% [markdown]
# We can use pprint() method for this
