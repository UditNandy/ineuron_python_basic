# %% [markdown]
# ### 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# 1.Function helps us in writing a specific task at once so that the entire program can call that function whenever required instead of writing the same function again and again
#
# 2.Function makes spotting the errors in program easy
#
# 3.They helps us write an eye catching code without making it too much messy

# %% [markdown]
# ### 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# ### 3. What statement creates a function?

# %% [markdown]
# def

# %% [markdown]
# ### 4. What is the difference between a function and a function call?

# %% [markdown]
# Fuction:It is a block of code written to perform a specific task
#
# Function Call:It is the request that we make to the function to give us the required result

# %% [markdown]
# ### 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# There is only one global scope in python
#
# There are four local scope in python

# %% [markdown]
# ### 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# The variable exists till the time the scope exist

# %% [markdown]
# ### 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# The value that a function gives is known as return value
#
# Yes it is possible to have a return value in an expression

# %% [markdown]
# ### 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# Void

# %% [markdown]
# ### 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# We can do it by using the global keyword

# %% [markdown]
# ### 10. What is the data type of None?

# %% [markdown]
# None is a datatype of own i.e. NoneType

# %% [markdown]
# ### 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# It imports amodule named areallyourpetsnamederic

# %% [markdown]
# ### 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# import spam
#
# spam.bacon()

# %% [markdown]
# ### 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# We can use the concept of exception handling here by putting the block of code in try

# %% [markdown]
# ### 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# try: clause looks whether the code present inside it's block is throwing an error or not
#
# except: If try block finds some error in it then it will be handled by the except block
