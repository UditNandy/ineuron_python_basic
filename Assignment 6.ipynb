# %% [markdown]
# ### 1. What are escape characters, and how do you use them?

# %% [markdown]
# We use escape characters to insert a character which is illegal in a string.We can use them using a '\'

# %% [markdown]
# ### 2. What do the escape characters n and t stand for?

# %% [markdown]
# n:new line
# t:tab space

# %% [markdown]
# ### 3. What is the way to include backslash characters in a string?

# %% [markdown]
# We can use two blackslashes to represnt a backslah

# %% [markdown]
# ### 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [markdown]
# Here we are using " to represent the end points of string so ' didnot caused a problem

# %% [markdown]
# ### 5. How do you write a string of newlines if you don't want to use the n character?

# %%
#We can simply write a statement in between two strings without any arguments
print('Hello')
print()
print('Hello')

# We can also use the end keyword
# Out:
# Hello
#
# Hello

# %% [markdown]
# ### 6. What are the values of the given expressions?
#
#
# 'Hello, world!'[1]:e
#
# 'Hello, world!'[0:5]:Hello
#
# 'Hello, world!'[:5]:Hello
#
# 'Hello, world!'[3:]:lo, world!

# %% [markdown]
# ### 7. What are the values of the following expressions?
# 'Hello'.upper()
#
# 'Hello'.upper().isupper()
#
# 'Hello'.upper().lower()

# %%
print('Hello'.upper())
print('Hello'.upper().isupper())
print('Hello'.upper().lower())
# Out:
# HELLO
# True
# hello

# %% [markdown]
# ### 8. What are the values of the following expressions?
# 'Remember, remember, the fifth of July.'.split()
# '-'.join('There can only one.'.split())

# %%
lst='Remember, remember, the fifth of July.'.split()

st='-'.join('There can only one.'.split())
print(lst)
print(st)
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
# There-can-only-one.

# %% [markdown]
# ### 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# The methods are ljust(),rjust() and center()

# %% [markdown]
# ### 10. What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# We can use the trim method
