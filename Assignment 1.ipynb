# %% [markdown]
# ### 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# *:expression
#
# 'hello':value
#
# -87.8:value
#
# -:expression
#
# /:expression
#
# +:expression
#
# 6:value

# %% [markdown]
# ### 2. What is the difference between string and variable?

# %% [markdown]
# String:It is a collection of characters
#
# Variable:Anything that stores a value in a program

# %% [markdown]
# ### 3. Describe three different data types.

# %% [markdown]
# Numeric:This includes int flot and complex
#
# Sequence:This includes list,tuples,range,etc
#
# Text:This includes characters or string

# %% [markdown]
# ### 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# An expression conisits of operators like +,-,etc and operands like values,variables.These expressions are used for evaluating values

# %% [markdown]
# ### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# In this case spam=10 is a statement which is assigning a value.So a statement generally represents an action where as an expression helps in finding out a value

# %% [markdown]
# ### 6. After running the following code, what does the variable bacon contain?
# ### bacon = 22
# ### bacon + 1

# %%
bacon=22
bacon+1
print(bacon)
# Out:
# 22

# %% [markdown]
# Here we can see that bacon contains its initial value.The value would have incremented if we had assigned baconwith bacon+1 i.e. bacon=bacon+1

# %% [markdown]
# ### 7.What should the values of the following two terms be?
# ### 'spam' + 'spamspam'
# ### 'spam' * 3

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %% [markdown]
# So we can clearly see that the value of both the statements are same

# %% [markdown]
# ### 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Any variable name canno start with a number so 100 is not a valid variable

# %% [markdown]
# ### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# int(),float(),str() are the functions to get string version of a value

# %% [markdown]
# ### 10. Why does this expression cause an error? How can you fix it?

# %%
'I have eaten ' + 99 + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d24137131a5c> in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Here 99 should be a string value

# %%
'I have eaten ' + '99' + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
