# %% [markdown]
# ### 1.To what does a relative path refer?

# %% [markdown]
# Path that is relative to the current directory is known as relative path

# %% [markdown]
# ### 2.What does an absolute path start with your operating system?

# %% [markdown]
# It refers to the total path starting from the root folder to the sub folder

# %% [markdown]
# ### 3.What do the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# os.getcwd():shows the current directory in which we are working
#
# os.chdir():Changes the current working directory to the given path

# %% [markdown]
# ### 4.What are the . and .. folders?

# %% [markdown]
# . -represents current directory
#
# .. - represents parent directory

# %% [markdown]
# ### 5.In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

# %% [markdown]
# base name:C:\bacon\eggs\
#
# dir name:spam.txt

# %% [markdown]
# ### 6. What are the three “mode” arguments that can be passed to the open() function?

# %% [markdown]
# r - read only
#
# r+ - read and write
#
# rb - read only in binary mode
#
# w - wirte only
#
# w+ -writing and reading
#
# wb -write only in binary mode

# %% [markdown]
# ### 7.What happens if an existing file is opened in write mode?

# %% [markdown]
# If the an existing file is opened then its contents are discarded and it is treated as a new file

# %% [markdown]
# ### 8. How do you tell the difference between read() and readlines()?

# %% [markdown]
# read(): It is used to read a single character from standard output device
#
# readlines(): It is used to read a line or string from standard output device

# %% [markdown]
# ### 9. What data structure does a shelf value resemble?

# %% [markdown]
# dictionary
